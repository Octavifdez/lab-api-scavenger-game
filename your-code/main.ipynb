# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import requests
import pandas as pd
import json
import re

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here
user = 'Octavifdez'
token = '9a73c05bfee046eb3cd2adabcaec4d4e493d83f7'
url = 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks'

response = requests.get(url, auth=(user,token))
print('Respones:', response)

result = response.json()
# Out:
# Respones: <Response [200]>

# %%
print(json.dumps(result, indent=4))
# Out:
# [
#     {
#         "id": 220066216,
#         "node_id": "MDEwOlJlcG9zaXRvcnkyMjAwNjYyMTY=",
#         "name": "mad-oct-2018",
#         "full_name": "ToniPons97/mad-oct-2018",
#         "private": false,
#         "owner": {
#             "login": "ToniPons97",
#             "id": 45130294,
#             "node_id": "MDQ6VXNlcjQ1MTMwMjk0",
#             "avatar_url": "https://avatars3.githubusercontent.com/u/45130294?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/ToniPons97",
#             "html_url": "https://github.com/ToniPons97",
#             "followers_url": "https://api.github.com/users/ToniPons97/followers",
#             "following_url": "https://api.github.com/users/ToniPons97/following{/other_user}",
#             "gists_url": "https://api.github.com/users/ToniPons97/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/ToniPons97/starred{/owner}{/repo}",
# ...

# %%
df = pd.DataFrame(result)
df
# Out:
#            id                           node_id             name  \
# 0   220066216  MDEwOlJlcG9zaXRvcnkyMjAwNjYyMTY=     mad-oct-2018
# 1   204100911  MDEwOlJlcG9zaXRvcnkyMDQxMDA5MTE=     mad-oct-2018
# 2   200138127  MDEwOlJlcG9zaXRvcnkyMDAxMzgxMjc=     mad-oct-2018
# 3   198273438  MDEwOlJlcG9zaXRvcnkxOTgyNzM0Mzg=     mad-oct-2018
# 4   167001044  MDEwOlJlcG9zaXRvcnkxNjcwMDEwNDQ=      datamad0119
# 5   162498469  MDEwOlJlcG9zaXRvcnkxNjI0OTg0Njk=  madrid-oct-2018
# 6   154625001  MDEwOlJlcG9zaXRvcnkxNTQ2MjUwMDE=  madrid-oct-2018
# 7   154291113  MDEwOlJlcG9zaXRvcnkxNTQyOTExMTM=  madrid-oct-2018
# 8   154191482  MDEwOlJlcG9zaXRvcnkxNTQxOTE0ODI=  madrid-oct-2018
# 9   154163166  MDEwOlJlcG9zaXRvcnkxNTQxNjMxNjY=  madrid-oct-2018
# 10  154105473  MDEwOlJlcG9zaXRvcnkxNTQxMDU0NzM=  madrid-oct-2018
# 11  153788059  MDEwOlJlcG9zaXRvcnkxNTM3ODgwNTk=  madrid-oct-2018
# 12  153787890  MDEwOlJlcG9zaXRvcnkxNTM3ODc4OTA=  madrid-oct-2018
# ...

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# your code here
language_result = df['language']
languages_used = language_result.unique()
languages_used
# Out:
# array([None, 'Jupyter Notebook', 'HTML', 'Python'], dtype=object)

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here

user = 'Octavifdez'
token = '9a73c05bfee046eb3cd2adabcaec4d4e493d83f7'
url2 = 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits'

response2 = requests.get(url, auth=(user,token))
print('Respones:', response2)

result2 = response.json()
# Out:
# Respones: <Response [200]>

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here
len(pd.DataFrame(result2))
# Out:
# 16

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here
user = 'Octavifdez'
token = '9a73c05bfee046eb3cd2adabcaec4d4e493d83f7'
url3 = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/'
# sha = '2945e51c87ad5da893c954afcf092f06343bbb7d'
# url3 = 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/'+sha

response3 = requests.get(url3, auth=(user,token))
print('Response:', response2)

result3 = response3.json()
# Out:
# Response: <Response [200]>

# %%
url4 = 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/'+'2945e51c87ad5da893c954afcf092f06343bbb7d'

response4 = requests.get(url4, auth=(user,token))
result4 = response4.json()
print(json.dumps(result4, indent=4))
# Out:
# {
#     "sha": "2945e51c87ad5da893c954afcf092f06343bbb7d",
#     "url": "https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d",
#     "tree": [
#         {
#             "path": ".0006.scavengerhunt",
#             "mode": "100644",
#             "type": "blob",
#             "sha": "1c9064284a24b3486015eafdb391b141c27ada2b",
#             "size": 3,
#             "url": "https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b"
#         },
#         {
#             "path": "40",
#             "mode": "100644",
#             "type": "blob",
#             "sha": "e69de29bb2d1d6434b8b29ae775ad8c2e48c5391",
#             "size": 0,
#             "url": "https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391"
#         },
#         {
#             "path": "74",
#             "mode": "100644",
#             "type": "blob",
# ...

# %%
user = 'Octavifdez'
token = '9a73c05bfee046eb3cd2adabcaec4d4e493d83f7'
pattern = '(scavengerhunt)$'

def find_file(sha,file_number):
    url4 = 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/'+sha

    response4 = requests.get(url4, auth=(user,token))
    result4 = response4.json()
    scavenge_list = []

    for i in range(len(result4['tree'])):
        current = result4['tree'][i]['path']
        result = result4['tree'][i]['url']
        if bool(re.search(pattern,current)):
#             print(f'In file {file_number}, file {current}')
            scavenge_list.append(result) 
    return scavenge_list
    
        
final_list = []
for i in range(len(data.sha)):
    if data.types[i] == 'dir':
        temp_list = find_file(data.sha[i], i)
        if len(temp_list) > 0:
            for i in range(len(temp_list)):
                final_list.append(temp_list[i])

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here
final_list.sort()
final_list
# Out:
# ['https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/04d0ffb8d895a9e3ee244493e829a24468bd1f60',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/09e16f36b3c4993ba924b1074629283a49869be9',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1269488f7fb1f4b56a8c0e5eb48cecbfadfa9219',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1a00a70b240d8947af0aaa04f1a93a52c72f7420',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/209e3ef4b6247ce746048d5711befda46206d235',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/2add7632f1323136324efbf38ec66db1838b6173',
# ...

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here
user = 'Octavifdez'
token = '9a73c05bfee046eb3cd2adabcaec4d4e493d83f7'

def find_file(sha,file_number):
    url4 = 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/'+sha

    response4 = requests.get(url4, auth=(user,token))
    result4 = response4.json()
    scavenge_list = []

    for i in range(len(result4['tree'])):
        current_file = result4['tree'][i]['path']
        current_url = result4['tree'][i]['url']
        if bool(re.search(pattern,current_file)):
#             print(f'In file {file_number}, file {current}')
            scavenge_list.append((current_file, current_url)) 
#             scavenge_list.append(current_url) 
    return scavenge_list
    
        
final_list = []
for i in range(len(data.sha)):
    if data.types[i] == 'dir':
        temp_list = find_file(data.sha[i], i)
        if len(temp_list) > 0:
            for i in range(len(temp_list)):
                final_list.append(temp_list[i])

# %%
final_list.sort()
sorted_list = []
for i in range(len(final_list)):
    sorted_list.append(final_list[i][1])
sorted_list[0]
# Out:
# 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/2add7632f1323136324efbf38ec66db1838b6173'

# %%
url5 = 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/2add7632f1323136324efbf38ec66db1838b6173'


# response5 = requests.get(url5, auth=(user,token), headers = {'Accept': 'application/vnd.github.v3.raw'})
response5 = requests.get(url5, auth=(user,token))

result5 = response5.json()
print(result5['content'])
# Out:
# SW4K

# %%
encoded_list = []
for i in range(len(sorted_list)):
    url5 = sorted_list[i]
    response5 = requests.get(url5, auth=(user,token))
    result5 = response5.json()
    encoded_list.append(result5['content'])

encoded_list
# Out:
# ['SW4K\n',
#  'ZGF0YQo=\n',
#  'c2NpZW5jZSwK\n',
#  'ODAK\n',
#  'cGVyY2VudAo=\n',
#  'b2YK\n',
#  'dGltZQo=\n',
#  'c3BlbnQK\n',
#  'aXMK\n',
#  'cHJlcGFyaW5nCg==\n',
#  'ZGF0YSwK\n',
#  'MjAK\n',
#  'cGVyY2VudAo=\n',
#  'b2YK\n',
#  'dGltZQo=\n',
#  'aXMK\n',
#  'c3BlbnQK\n',
#  'Y29tcGxhaW5pbmcK\n',
#  'YWJvdXQK\n',
#  'dGhlCg==\n',
#  'bmVlZAo=\n',
#  'dG8K\n',
#  'cHJlcGFyZQo=\n',
#  'ZGF0YS4K\n']

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here
import base64

# base64_message = encoded_list[1]
# base64_bytes = base64_message.encode('ascii')
# message_bytes = base64.b64decode(base64_bytes)
# message = message_bytes.decode('ascii')
# message


import base64
def decoding(word_to_decode):
    base64_message = word_to_decode
    base64_bytes = base64_message.encode('ascii')
    message_bytes = base64.b64decode(base64_bytes)
    message = message_bytes.decode('ascii')
    return message
    
decoded_list = []
for i in range(len(encoded_list)):
    word = decoding(encoded_list[i])
    decoded_list.append(word)

joke = ''
for i in range(len(decoded_list)):
    joke = joke + ' ' + decoded_list[i]

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
print(joke)
# Out:
#  In
#  data
#  science,
#  80
#  percent
#  of
#  time
#  spent
#  is
#  preparing
#  data,
#  20
#  percent
#  of
#  time
#  is
#  spent
#  complaining
#  about
#  the
#  need
#  to
#  prepare
#  data.
